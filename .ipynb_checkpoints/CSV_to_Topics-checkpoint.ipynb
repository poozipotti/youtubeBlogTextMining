# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from gensim import corpora, models, similarities
import re
from nltk.tokenize import MWETokenizer

# %%
#variables
blog_df = pd.read_csv("CLEANER_CLEAN_BLOG.csv")
#"dictionary" is the corpus dictionary generated when the documents are turned into vectors, it declared later
#stopwords list load into memory
stopwords = [re.sub('\n','', line) for line in open("stopwords.txt")]

# %%
#sort the csv and drop empty cells 
blog_df['date'] = pd.to_datetime(blog_df['date'])
blog_df = blog_df.dropna(how="any")
blog_df = blog_df.sort_values(by="date")
blog_df.head()
# Out:
#          date                                               body  \
# 36 2005-07-09  You can now add a field for quotDate Recordedq...
# 38 2005-07-23  Many people have asked us how to put a list of...
# 35 2005-07-24  You know I really cant believe the pace that w...
# 33 2005-07-27  Its now possible to put an HTML snippet on you...
# 40 2005-08-11  We are ecstatic to announce the changes we mad...
#
#                                        tokenized_body  \
# 36  [add, field, quotdate, recordedquot, quotlocat...
# 38   [people, list, videos, , , people, list, videos]
# 35  [cant, believe, pace, releasing, features, mea...
# 33  [html, snippet, website, automatically, pulls,...
# 40  [ecstatic, announce, changes, site, night, res...
#
#                                          bag_of_words
# 36  [(0, 1), (1, 2), (2, 2), (3, 2), (4, 2), (5, 2...
# 38                [(0, 2), (14, 2), (16, 2), (17, 2)]
# 35  [(0, 1), (18, 2), (19, 2), (20, 2), (21, 2), (...
# 33  [(0, 1), (13, 2), (14, 6), (26, 4), (27, 2), (...
# 40  [(0, 3), (29, 2), (37, 2), (38, 4), (39, 2), (...

# %%
#format or gensim using bag-of-words method
blog_df["tokenized_body"] = blog_df["body"].map(lambda paragraph: filter(lambda word: word not in stopwords,paragraph.lower().split(" ")))
#generate the gensim dictionary of all the words in the corpus
#TODO this should be tweaked it is very simplistic, need a topwords list etc.
#special thanks https://stackoverflow.com/questions/36250297/how-to-map-the-word-in-data-frame-to-integer-id-with-python-pandas-and-gensim
dictionary = corpora.Dictionary(blog_df["tokenized_body"])
dictionary.filter_extremes(no_below=1,no_above=1,keep_n=5000)
blog_df["bag_of_words"] = blog_df["tokenized_body"].map(dictionary.doc2bow)
blog_df.head()
# Out:
#          date                                               body  \
# 36 2005-07-09  You can now add a field for quotDate Recordedq...
# 38 2005-07-23  Many people have asked us how to put a list of...
# 35 2005-07-24  You know I really cant believe the pace that w...
# 33 2005-07-27  Its now possible to put an HTML snippet on you...
# 40 2005-08-11  We are ecstatic to announce the changes we mad...
#
#                                        tokenized_body  \
# 36  [add, field, quotdate, recordedquot, quotlocat...
# 38   [people, list, videos, , , people, list, videos]
# 35  [cant, believe, pace, releasing, features, mea...
# 33  [html, snippet, website, automatically, pulls,...
# 40  [ecstatic, announce, changes, site, night, res...
#
#                                          bag_of_words
# 36  [(0, 1), (1, 2), (2, 2), (3, 2), (4, 2), (5, 2...
# 38                [(0, 2), (14, 2), (16, 2), (17, 2)]
# 35  [(0, 1), (18, 2), (19, 2), (20, 2), (21, 2), (...
# 33  [(0, 1), (13, 2), (14, 6), (26, 4), (27, 2), (...
# 40  [(0, 3), (29, 2), (37, 2), (38, 4), (39, 2), (...

# %%
#THIS TAKES A LONG TIME
#make the corpus object for gensim from blog_df
#relevant documentation copied from gensim website
corpus=blog_df["bag_of_words"]
tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]
#latent semeantic indexing
#transform the tf-ldf corpus into a bunch of topixs
#lsi=models.LsiModel(corpus_tfidf,id2word=dictionary, num_topics=200)
#lda is supposed to make more sense
lda = models.ldamodel.LdaModel(corpus=corpus_tfidf, id2word=dictionary, num_topics=20, update_every=0, passes=40)
#corpus_lsi = lsi[corpus_tfidf]
#lsi.print_topics(200)
#lda.print_topics(200)

# %%
lda.print_topics()
# Out:
# [(0,
#   u'0.004*"suggestions" + 0.004*"8220" + 0.004*"based" + 0.004*"ramya" + 0.004*"raghavan" + 0.003*"minds" + 0.003*"update" + 0.003*"manager" + 0.003*"watched" + 0.003*"recently"'),
#  (1,
#   u'0.003*"lately" + 0.003*"policies" + 0.003*"preview" + 0.002*"4k" + 0.002*"pinterest" + 0.002*"organizers" + 0.002*"determine" + 0.002*"inventory" + 0.002*"pornographers" + 0.002*"talking"'),
#  (2,
#   u'0.009*"june" + 0.007*"recently" + 0.007*"e3" + 0.005*"mia" + 0.005*"festival" + 0.004*"quagliarello" + 0.003*"highlights" + 0.003*"venice" + 0.003*"trailers" + 0.003*"premiere"'),
#  (3,
#   u'0.009*"ago" + 0.008*"team" + 0.008*"weeks" + 0.008*"launched" + 0.008*"announce" + 0.007*"congratulations" + 0.005*"sports" + 0.005*"excited" + 0.003*"links" + 0.003*"title"'),
#  (4,
#   u'0.010*"nonprofits" + 0.010*"activism" + 0.006*"information" + 0.005*"vr" + 0.005*"percent" + 0.005*"manager" + 0.005*"amp" + 0.005*"entertainment" + 0.004*"conversation" + 0.004*"brands"'),
#  (5,
#   u'0.015*"everyday" + 0.010*"month" + 0.005*"unfold" + 0.004*"youtubenbsp" + 0.004*"earlier" + 0.004*"volunteers" + 0.004*"news" + 0.003*"additions" + 0.003*"curator" + 0.003*"citizens"'),
#  (6,
#   u'0.046*"weekday" + 0.041*"trending" + 0.038*"whats" + 0.026*"day" + 0.023*"check" + 0.005*"youtube" + 0.005*"calling" + 0.005*"sketch" + 0.005*"round" + 0.004*"ambassadors"'),
#  (7,
#   u'0.018*"film" + 0.008*"welcome" + 0.007*"march" + 0.007*"launch" + 0.005*"team" + 0.004*"youtube" + 0.003*"union" + 0.003*"morning" + 0.003*"president" + 0.003*"speech"'),
#  (8,
#   u'0.007*"videos" + 0.007*"video" + 0.006*"music" + 0.006*"youtube" + 0.005*"live" + 0.005*"people" + 0.005*"channel" + 0.005*"world" + 0.004*"watch" + 0.004*"we8217re"'),
#  (9,
#   u'0.017*"58821" + 0.008*"false" + 0.008*"160" + 0.008*"var" + 0.005*"name" + 0.004*"summaryhtml" + 0.003*"url" + 0.003*"null" + 0.003*"data" + 0.003*"email"'),
#  (10,
#   u'0.030*"politics" + 0.026*"news" + 0.010*"senator" + 0.008*"08" + 0.008*"week" + 0.006*"spotlight" + 0.006*"choose" + 0.005*"youtube" + 0.005*"subscribe" + 0.005*"launch"'),
#  (11,
#   u'0.039*"" + 0.013*"hi" + 0.005*"film" + 0.004*"cannes" + 0.004*"wondered" + 0.004*"2009" + 0.004*"wii" + 0.003*"xbox" + 0.003*"bruno" + 0.003*"shooting"'),
#  (12,
#   u'0.008*"hey" + 0.007*"convention" + 0.006*"2010" + 0.005*"july" + 0.005*"republican" + 0.005*"international" + 0.005*"party" + 0.004*"democratic" + 0.004*"festival" + 0.003*"official"'),
#  (13,
#   u'0.035*"team" + 0.023*"week" + 0.008*"youtube" + 0.007*"earlier" + 0.007*"film" + 0.005*"marks" + 0.004*"governor" + 0.004*"japanese" + 0.004*"heres" + 0.004*"valentines"'),
#  (14,
#   u'0.006*"sundance" + 0.005*"festival" + 0.003*"sneak" + 0.003*"annual" + 0.003*"weekend" + 0.003*"ongoing" + 0.003*"guitar" + 0.003*"shorts" + 0.003*"updates" + 0.003*"thrilling"'),
#  (15,
#   u'0.004*"fashion" + 0.004*"thanksgiving" + 0.003*"8211" + 0.003*"celebrity" + 0.003*"hottest" + 0.003*"passion" + 0.003*"upandcoming" + 0.003*"expert" + 0.003*"christmas" + 0.003*"nominees"'),
#  (16,
#   u'0.005*"paramnameallowfullscreen" + 0.005*"permalink" + 0.005*"timestamp" + 0.005*"displaytime" + 0.005*"author" + 0.004*"body" + 0.003*"lh3googleusercontentcomzfdxge77vvd2w5xhy6jkvuelkvu99qlkryk8onbdejptjsz82upq5w6hjsax3ds35" + 0.003*"suggestions" + 0.003*"famous" + 0.003*"changes"'),
#  (17,
#   u'0.005*"howto" + 0.005*"food" + 0.005*"annual" + 0.004*"diy" + 0.004*"posted" + 0.004*"annotations" + 0.003*"originals" + 0.002*"planning" + 0.002*"joining" + 0.002*"cause"'),
#  (18,
#   u'0.003*"comiccon" + 0.003*"paris" + 0.003*"freedom" + 0.003*"usa" + 0.003*"adopt" + 0.003*"eyes" + 0.003*"rolled" + 0.002*"diego" + 0.002*"stop" + 0.002*"exceeded"'),
#  (19,
#   u'0.023*"var" + 0.008*"id" + 0.008*"null" + 0.007*"return" + 0.005*"replybox" + 0.005*"cursor" + 0.005*"commentid" + 0.005*"blogadmin" + 0.005*"deleteclass" + 0.005*"avatarurl"')]

# %%
blog_df["associated_topics"] =  lda.get_document_topics(blog_df["bag_of_words"])
#this is only getting the first topic not the most relevant for testing but 
#it needs to be fixed
blog_df["main_topic"] =  [topics[0][0] for topics in lda.get_document_topics(blog_df["bag_of_words"])]

blog_df.head()
# Out:
#          date                                               body  \
# 36 2005-07-09  You can now add a field for quotDate Recordedq...
# 38 2005-07-23  Many people have asked us how to put a list of...
# 35 2005-07-24  You know I really cant believe the pace that w...
# 33 2005-07-27  Its now possible to put an HTML snippet on you...
# 40 2005-08-11  We are ecstatic to announce the changes we mad...
#
#                                        tokenized_body  \
# 36  [add, field, quotdate, recordedquot, quotlocat...
# 38   [people, list, videos, , , people, list, videos]
# 35  [cant, believe, pace, releasing, features, mea...
# 33  [html, snippet, website, automatically, pulls,...
# 40  [ecstatic, announce, changes, site, night, res...
#
#                                          bag_of_words  \
# 36  [(0, 1), (1, 2), (2, 2), (3, 2), (4, 2), (5, 2...
# 38                [(0, 2), (14, 2), (16, 2), (17, 2)]
# 35  [(0, 1), (18, 2), (19, 2), (20, 2), (21, 2), (...
# 33  [(0, 1), (13, 2), (14, 6), (26, 4), (27, 2), (...
# 40  [(0, 3), (29, 2), (37, 2), (38, 4), (39, 2), (...
#
#                                     associated_topics  main_topic
# 36  [(4, 0.22377044), (8, 0.57976365), (11, 0.0278...           4
# 38                [(8, 0.67272156), (11, 0.22727847)]           8
# 35                [(8, 0.88231397), (11, 0.06768602)]           8
# 33  [(0, 0.045090523), (1, 0.22241575), (8, 0.6851...           0
# 40  [(8, 0.18896124), (11, 0.100578815), (16, 0.68...           8

# %%
#this seems suspect
blog_df.plot.bar(x="date",y="main_topic",title="topic with time",figsize=(20,10))
